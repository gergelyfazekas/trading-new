# %%
from stock_class import Stock, StockList
from portfolio_class import Portfolio, PortfolioList
from broker import IBroker
import pandas as pd 
import numpy as np
import time
import cProfile, pstats, io
import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed
from concurrent.futures import ProcessPoolExecutor

# constants
from config import ticker_list, bronze, silver, gold, forecast_folder, model_folder, model_meta_file, portfolio_folder

# %%
stock_list = StockList(tickers)
stock_list.load_data(path=gold)

portfolio = Portfolio(stock_list=stock_list, features=tickers)

broker = IBroker()
broker.connect()
# Out:
# Sector not found. Assigning `Unknown`
# Sector not found. Assigning `Unknown`
# Sector not found. Assigning `Unknown`
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 12
#       9 portfolio = Portfolio(stock_list=stock_list, features=tickers)
#      11 broker = IBroker()
# ---> 12 broker.connect()
#
# File ~/Documents/python_projects/trading_new_structure/broker.py:13, in IBroker.connect(self)
#      11 def connect(self):
#      12     # Connect to IB Gateway or TWS
# ---> 13     self.ib.connect('127.0.0.1', 4002, clientId=1)
#
# File ~/Documents/python_projects/trading_new_structure/venv/lib/python3.9/site-packages/ib_insync/ib.py:279, in IB.connect(self, host, port, clientId, timeout, readonly, account)
#     257 def connect(
#     258         self, host: str = '127.0.0.1', port: int = 7497, clientId: int = 1,
# ...

# %%
for ticker in tickers:
    broker.get_stock_price(ticker)
    time.sleep(3)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[3], line 2
#       1 for ticker in tickers:
# ----> 2     broker.get_stock_price(ticker)
#       3     time.sleep(3)
#
# File ~/Documents/python_projects/trading_new_structure/broker.py:44, in IBroker.get_stock_price(self, ticker, snapshot)
#      42 def get_stock_price(self, ticker, snapshot=False):
#      43     stock = Stock(ticker, 'SMART', 'USD')
# ---> 44     self.ib.qualifyContracts(stock)
#      45     market_data_type = self.ib.reqMarketDataType(3)
#      46     market_data = self.ib.reqMktData(stock, '', snapshot, False)
#
# File ~/Documents/python_projects/trading_new_structure/venv/lib/python3.9/site-packages/ib_insync/ib.py:570, in IB.qualifyContracts(self, *contracts)
#     558 def qualifyContracts(self, *contracts: Contract) -> List[Contract]:
#     559     """
# ...

# %%
p.load_weights('/Users/gergelyfazekas/Documents/python_projects/trading_new_structure/data/portfolios/gen3_id0_2025-07-14 14:38:25.321841.json')

# %%
# We should go from pulling the IBKR data to having a forecast for the next day
forecasts = [1,2,3]
df = pd.DataFrame(dict(zip(tickers, forecasts)), index=[datetime.datetime.now()])

# %%
p.decide(dt=df.index[0], data=df.to_numpy())

# %%
p.decision_to_action(decision=p.decide(dt=df.index[0], data=df.to_numpy()))

# %%
df = pd.DataFrame({'a':[1,2,3], 'b':[4,5,6]})
pd.DataFrame(dict(df.iloc[-1, :]), index=[df.iloc[-1, :].name])
# Out:
#    a  b
# 2  3  6

# %%
df.iloc[0, 0] = np.nan

# %%
df[df.isna().any(axis=1)]
# Out:
#     a  b
# 0 NaN  4
